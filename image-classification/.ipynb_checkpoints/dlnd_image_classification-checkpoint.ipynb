# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 5
sample_id = 2
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 5:
# Samples: 10000
# Label Counts: {0: 1014, 1: 1014, 2: 952, 3: 1016, 4: 997, 5: 1025, 6: 980, 7: 977, 8: 1003, 9: 1022}
# First 20 Labels: [1, 8, 5, 1, 5, 7, 4, 3, 8, 2, 7, 2, 0, 1, 5, 9, 6, 2, 0, 8]
#
# Example of Image 2:
# Image - Min Value: 0 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 5 Name: dog

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
import math

def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    : notes
    
        Formula for normalize data in the range of 0 to 1 is 
        
        zi = xi − min(x) / max(x) − min(x)
        
    """
    return (x - np.min(x)) / (np.max(x) - np.min(x))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(z, num_class=10):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    
    @see https://docs.scipy.org/doc/numpy-1.10.1/reference/generated/numpy.eye.html
    """
    # First method
    return np.eye(num_class)[z]
     
    
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,shape=[None, *image_shape], name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,shape=[None, n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # Weight and bias
    weight = tf.Variable(
        tf.truncated_normal(
            [
                *conv_ksize, 
                x_tensor.get_shape().as_list()[3], 
                conv_num_outputs
            ], 
            mean=0, 
            stddev=0.05
        )
    )
    bias = tf.Variable(
        tf.zeros(
            conv_num_outputs
        )
    )
    
    # apply convolution
    cv = tf.nn.conv2d(
        x_tensor, 
        weight, 
        strides=[
            1, 
            *conv_strides,
            1
        ], 
        padding='SAME'
    )
    
    # add bias
    cv = tf.nn.bias_add(cv, bias)
    
    # add a nonlinear activation to the convolution
    cv = tf.nn.relu(cv)
    
    # apply Max Pooling using pool_ksize and pool_strides
    
    cv = tf.nn.max_pool(
        cv, ksize=[
            1, 
            *pool_ksize, 
            1
        ],strides=[
            1, 
            *pool_strides, 
            1
        ], padding='SAME'
    )
    
    # finnaly return the computation
    return cv 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
import numpy
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    
    Notes
    -----
        @see https://www.tensorflow.org/api_docs/python/tf/reshape
        
        # tensor 't' is [[[1, 1, 1],
        #                 [2, 2, 2]],
        #                [[3, 3, 3],
        #                 [4, 4, 4]],
        #                [[5, 5, 5],
        #                 [6, 6, 6]]]
        # tensor 't' has shape [3, 2, 3]
        # pass '[-1]' to flatten 't'
        reshape(t, [-1]) ==> [1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4, 5, 5, 5, 6, 6, 6]
        
    """
    # assert there are no more than one unknown dimension or die
    # http://stackoverflow.com/questions/36668542/flatten-batch-in-tensorflow
    
    assert len([s for s in x_tensor.get_shape().as_list() if s is None]) == 1
    m = tf.reshape(
        x_tensor, [-1, numpy.prod([s for s in x_tensor.get_shape().as_list() if s is not None])]
    )
    return m
     


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # Weight and bias
    weight = tf.Variable(
        tf.truncated_normal(
            [x_tensor.get_shape().as_list()[1], num_outputs], mean=0, stddev=0.05
        )
    )
    bias = tf.Variable(tf.zeros(num_outputs))
    # Linear function WX + b
    _ = tf.matmul(x_tensor, weight)
    
    _ = tf.nn.bias_add(_, bias)

    # ReLU activation
    _ =  tf.nn.relu(_)
    
    return _



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # Weight and bias
    weight = tf.Variable(
        tf.truncated_normal(
            [x_tensor.get_shape().as_list()[1], num_outputs], mean=0, stddev=0.05
        )
    )
    bias = tf.Variable(tf.zeros(num_outputs))
    # Linear function WX + b
    _ = tf.matmul(x_tensor, weight)
    
    _ = tf.nn.bias_add(_, bias)
    
    return _


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
   
    model = conv2d_maxpool(
        x, conv_num_outputs=64, conv_ksize=(3,3), conv_strides=(1,1), pool_ksize=(3,3), pool_strides=(2,2)
    )
    model = tf.nn.dropout(model, keep_prob)
    
    model = conv2d_maxpool(
        model, conv_num_outputs=32, conv_ksize=(3,3), conv_strides=(1,1), pool_ksize=(2,2), pool_strides=(2,2)
    )
    model = tf.nn.dropout(model, keep_prob)
    
    model = conv2d_maxpool(
        model, conv_num_outputs=64, conv_ksize=(3,3), conv_strides=(1,1), pool_ksize=(2,2), pool_strides=(2,2)
    )
    
    model = tf.nn.dropout(model, keep_prob)
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    
    model = flatten(model)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    model = fully_conn(model, 384)
    
    model = tf.nn.dropout(model, keep_prob)
    
    model = fully_conn(model, 192)
    
    model = tf.nn.dropout(model, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    logits = output(model, 10)
    # TODO: return output
    return logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer, feed_dict={
        x:feature_batch, 
        y:label_batch, 
        keep_prob:keep_probability
    })


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    loss = session.run(cost, feed_dict={x:feature_batch, y:label_batch, keep_prob:1.0})
    validation_accuracy = sess.run(accuracy, feed_dict={
                x: valid_features,
                y: valid_labels,
                keep_prob: 1.})
    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(
                loss,
                validation_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 256
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2664 Validation Accuracy: 0.186200
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.1771 Validation Accuracy: 0.252800
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.0943 Validation Accuracy: 0.313600
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.9982 Validation Accuracy: 0.343400
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.8879 Validation Accuracy: 0.375600
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.7829 Validation Accuracy: 0.405000
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.7208 Validation Accuracy: 0.424800
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.6402 Validation Accuracy: 0.440600
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.6040 Validation Accuracy: 0.435200
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.5429 Validation Accuracy: 0.457400
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.4529 Validation Accuracy: 0.476400
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.4116 Validation Accuracy: 0.491800
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.3643 Validation Accuracy: 0.499200
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.3245 Validation Accuracy: 0.499800
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.2734 Validation Accuracy: 0.504200
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.2644 Validation Accuracy: 0.507400
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.2183 Validation Accuracy: 0.517400
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.1750 Validation Accuracy: 0.521000
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.1394 Validation Accuracy: 0.531200
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.1013 Validation Accuracy: 0.546000
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.1243 Validation Accuracy: 0.539600
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.0880 Validation Accuracy: 0.540800
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.0429 Validation Accuracy: 0.537800
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.0196 Validation Accuracy: 0.546400
# Epoch 25, CIFAR-10 Batch 1:  Loss:     1.0160 Validation Accuracy: 0.544600
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.9837 Validation Accuracy: 0.552400
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.9364 Validation Accuracy: 0.569400
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.9568 Validation Accuracy: 0.551400
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.9612 Validation Accuracy: 0.560600
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.9246 Validation Accuracy: 0.571200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.8973 Validation Accuracy: 0.578800
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.8698 Validation Accuracy: 0.576400
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.8358 Validation Accuracy: 0.577200
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.8414 Validation Accuracy: 0.574000
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.8000 Validation Accuracy: 0.585200
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.7916 Validation Accuracy: 0.579400
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.7673 Validation Accuracy: 0.583600
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.7389 Validation Accuracy: 0.590000
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.7292 Validation Accuracy: 0.593400
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.7364 Validation Accuracy: 0.600200
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.6979 Validation Accuracy: 0.591000
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.6730 Validation Accuracy: 0.600800
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.6751 Validation Accuracy: 0.594000
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.6782 Validation Accuracy: 0.593400
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.6682 Validation Accuracy: 0.598000
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.6181 Validation Accuracy: 0.608000
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.5986 Validation Accuracy: 0.612200
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.6242 Validation Accuracy: 0.601400
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.5979 Validation Accuracy: 0.609800
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.5629 Validation Accuracy: 0.611000
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.5478 Validation Accuracy: 0.622600
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.5331 Validation Accuracy: 0.617800
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.5661 Validation Accuracy: 0.612600
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.5283 Validation Accuracy: 0.617400
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.5540 Validation Accuracy: 0.616200
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.5407 Validation Accuracy: 0.614400
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.4810 Validation Accuracy: 0.623000
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.4695 Validation Accuracy: 0.621600
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.4624 Validation Accuracy: 0.626000
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.4830 Validation Accuracy: 0.619400
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.4592 Validation Accuracy: 0.634600
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.4604 Validation Accuracy: 0.625000
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.4958 Validation Accuracy: 0.616200
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.4622 Validation Accuracy: 0.629000
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.4472 Validation Accuracy: 0.622000
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.4175 Validation Accuracy: 0.631200
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.4061 Validation Accuracy: 0.637000
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.4178 Validation Accuracy: 0.631400
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.4285 Validation Accuracy: 0.628400
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-0ebd1bbc35ad> in <module>()
#      11         batch_i = 1
#      12         for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
# ---> 13             train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
#      14         print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
#      15         print_stats(sess, batch_features, batch_labels, cost, accuracy)
#
# <ipython-input-30-1b1391a2c834> in train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch)
#      11         x:feature_batch,
#      12         y:label_batch,
# ---> 13         keep_prob:keep_probability
#      14     })
#      15
#
# /home/clement/.virtualenvs/udacity_nanodegree_deeplearning/lib64/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/clement/.virtualenvs/udacity_nanodegree_deeplearning/lib64/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/clement/.virtualenvs/udacity_nanodegree_deeplearning/lib64/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/clement/.virtualenvs/udacity_nanodegree_deeplearning/lib64/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/clement/.virtualenvs/udacity_nanodegree_deeplearning/lib64/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2909 Validation Accuracy: 0.135400
# Epoch  1, CIFAR-10 Batch 2:  Loss:     2.2588 Validation Accuracy: 0.204600
# Epoch  1, CIFAR-10 Batch 3:  Loss:     2.0075 Validation Accuracy: 0.184600
# Epoch  1, CIFAR-10 Batch 4:  Loss:     2.0382 Validation Accuracy: 0.223000
# Epoch  1, CIFAR-10 Batch 5:  Loss:     2.0028 Validation Accuracy: 0.305000
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.9746 Validation Accuracy: 0.358200
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.8215 Validation Accuracy: 0.367000
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.7869 Validation Accuracy: 0.320400
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.6968 Validation Accuracy: 0.381000
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.6704 Validation Accuracy: 0.400200
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.7523 Validation Accuracy: 0.444400
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.5434 Validation Accuracy: 0.450600
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.4164 Validation Accuracy: 0.415200
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.5500 Validation Accuracy: 0.462000
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.5344 Validation Accuracy: 0.455600
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.5553 Validation Accuracy: 0.487000
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.4140 Validation Accuracy: 0.485400
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.3371 Validation Accuracy: 0.454400
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.4764 Validation Accuracy: 0.471600
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.5857 Validation Accuracy: 0.436400
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.4161 Validation Accuracy: 0.517600
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.3875 Validation Accuracy: 0.514800
# Epoch  5, CIFAR-10 Batch 3:  Loss:     1.3715 Validation Accuracy: 0.467600
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.4619 Validation Accuracy: 0.458600
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.4633 Validation Accuracy: 0.465800
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.3942 Validation Accuracy: 0.529400
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.3299 Validation Accuracy: 0.492000
# Epoch  6, CIFAR-10 Batch 3:  Loss:     1.2174 Validation Accuracy: 0.515800
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.2590 Validation Accuracy: 0.533200
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.3536 Validation Accuracy: 0.492000
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.3946 Validation Accuracy: 0.513600
# Epoch  7, CIFAR-10 Batch 2:  Loss:     1.2841 Validation Accuracy: 0.516400
# Epoch  7, CIFAR-10 Batch 3:  Loss:     1.1573 Validation Accuracy: 0.534200
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.2267 Validation Accuracy: 0.540600
# Epoch  7, CIFAR-10 Batch 5:  Loss:     1.2334 Validation Accuracy: 0.523000
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.1818 Validation Accuracy: 0.550400
# Epoch  8, CIFAR-10 Batch 2:  Loss:     1.2903 Validation Accuracy: 0.519000
# Epoch  8, CIFAR-10 Batch 3:  Loss:     1.1666 Validation Accuracy: 0.532600
# Epoch  8, CIFAR-10 Batch 4:  Loss:     1.2158 Validation Accuracy: 0.535400
# Epoch  8, CIFAR-10 Batch 5:  Loss:     1.2494 Validation Accuracy: 0.523600
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.0796 Validation Accuracy: 0.575800
# Epoch  9, CIFAR-10 Batch 2:  Loss:     1.2028 Validation Accuracy: 0.547600
# Epoch  9, CIFAR-10 Batch 3:  Loss:     1.0280 Validation Accuracy: 0.569400
# Epoch  9, CIFAR-10 Batch 4:  Loss:     1.1897 Validation Accuracy: 0.532600
# Epoch  9, CIFAR-10 Batch 5:  Loss:     1.0730 Validation Accuracy: 0.569000
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.1416 Validation Accuracy: 0.572000
# Epoch 10, CIFAR-10 Batch 2:  Loss:     1.1814 Validation Accuracy: 0.570800
# Epoch 10, CIFAR-10 Batch 3:  Loss:     1.0401 Validation Accuracy: 0.573200
# Epoch 10, CIFAR-10 Batch 4:  Loss:     1.2334 Validation Accuracy: 0.520800
# Epoch 10, CIFAR-10 Batch 5:  Loss:     1.1618 Validation Accuracy: 0.531400
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.0692 Validation Accuracy: 0.596200
# Epoch 11, CIFAR-10 Batch 2:  Loss:     1.1415 Validation Accuracy: 0.590000
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.9203 Validation Accuracy: 0.606800
# Epoch 11, CIFAR-10 Batch 4:  Loss:     1.0823 Validation Accuracy: 0.580000
# Epoch 11, CIFAR-10 Batch 5:  Loss:     1.0538 Validation Accuracy: 0.567600
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.9969 Validation Accuracy: 0.604800
# Epoch 12, CIFAR-10 Batch 2:  Loss:     1.0931 Validation Accuracy: 0.589800
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.8977 Validation Accuracy: 0.608600
# Epoch 12, CIFAR-10 Batch 4:  Loss:     1.0216 Validation Accuracy: 0.598800
# Epoch 12, CIFAR-10 Batch 5:  Loss:     1.1222 Validation Accuracy: 0.570400
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.9540 Validation Accuracy: 0.616400
# Epoch 13, CIFAR-10 Batch 2:  Loss:     1.0562 Validation Accuracy: 0.618200
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.8683 Validation Accuracy: 0.634200
# Epoch 13, CIFAR-10 Batch 4:  Loss:     1.0092 Validation Accuracy: 0.609200
# Epoch 13, CIFAR-10 Batch 5:  Loss:     1.0467 Validation Accuracy: 0.583600
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.9398 Validation Accuracy: 0.638000
# Epoch 14, CIFAR-10 Batch 2:  Loss:     1.0181 Validation Accuracy: 0.604800
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.8896 Validation Accuracy: 0.615200
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.9824 Validation Accuracy: 0.610400
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.9832 Validation Accuracy: 0.592000
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.9288 Validation Accuracy: 0.629200
# Epoch 15, CIFAR-10 Batch 2:  Loss:     1.1105 Validation Accuracy: 0.591800
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.9223 Validation Accuracy: 0.623000
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.9700 Validation Accuracy: 0.604800
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.9525 Validation Accuracy: 0.593000
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.8987 Validation Accuracy: 0.646200
# Epoch 16, CIFAR-10 Batch 2:  Loss:     1.0527 Validation Accuracy: 0.597800
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.8735 Validation Accuracy: 0.634000
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.8344 Validation Accuracy: 0.639000
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.9164 Validation Accuracy: 0.602200
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.9176 Validation Accuracy: 0.627200
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.8861 Validation Accuracy: 0.653000
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.9070 Validation Accuracy: 0.628400
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.7991 Validation Accuracy: 0.641800
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.8597 Validation Accuracy: 0.641000
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.9004 Validation Accuracy: 0.621800
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.8794 Validation Accuracy: 0.656400
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.7545 Validation Accuracy: 0.644200
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.8583 Validation Accuracy: 0.622000
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.8960 Validation Accuracy: 0.609400
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.8417 Validation Accuracy: 0.639800
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.9392 Validation Accuracy: 0.646000
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.7735 Validation Accuracy: 0.638600
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.8943 Validation Accuracy: 0.618800
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.8091 Validation Accuracy: 0.635000
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.8378 Validation Accuracy: 0.651600
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.8725 Validation Accuracy: 0.652200
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.7296 Validation Accuracy: 0.642400
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.7177 Validation Accuracy: 0.659200
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.8709 Validation Accuracy: 0.618800
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.8642 Validation Accuracy: 0.633000
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.9450 Validation Accuracy: 0.616400
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.6824 Validation Accuracy: 0.661600
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.7415 Validation Accuracy: 0.650000
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.8964 Validation Accuracy: 0.626400
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.7878 Validation Accuracy: 0.662000
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.9086 Validation Accuracy: 0.650800
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.8108 Validation Accuracy: 0.620200
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.6687 Validation Accuracy: 0.657400
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.7872 Validation Accuracy: 0.644400
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.8502 Validation Accuracy: 0.660600
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.7736 Validation Accuracy: 0.672800
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.7487 Validation Accuracy: 0.649800
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.6330 Validation Accuracy: 0.678200
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.7957 Validation Accuracy: 0.647600
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.8627 Validation Accuracy: 0.638800
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.8187 Validation Accuracy: 0.658600
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.6597 Validation Accuracy: 0.659400
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.6418 Validation Accuracy: 0.683400
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.7492 Validation Accuracy: 0.654600
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.6945 Validation Accuracy: 0.687000
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.8063 Validation Accuracy: 0.673600
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.6031 Validation Accuracy: 0.671800
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.6904 Validation Accuracy: 0.664600
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.7904 Validation Accuracy: 0.654800
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.6955 Validation Accuracy: 0.677200
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.7663 Validation Accuracy: 0.666000
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.6103 Validation Accuracy: 0.673400
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.6051 Validation Accuracy: 0.688800
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.6993 Validation Accuracy: 0.673200
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.7648 Validation Accuracy: 0.653400
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.7141 Validation Accuracy: 0.678200
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.6116 Validation Accuracy: 0.680800
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.6981 Validation Accuracy: 0.655000
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.7252 Validation Accuracy: 0.663600
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.6942 Validation Accuracy: 0.692800
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.7851 Validation Accuracy: 0.626600
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.6500 Validation Accuracy: 0.667600
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.6429 Validation Accuracy: 0.671200
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.7217 Validation Accuracy: 0.659200
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.7318 Validation Accuracy: 0.668600
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.8029 Validation Accuracy: 0.642000
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.6048 Validation Accuracy: 0.686000
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.6139 Validation Accuracy: 0.685200
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.6386 Validation Accuracy: 0.684000
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.6731 Validation Accuracy: 0.693800
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.7433 Validation Accuracy: 0.692200
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.6732 Validation Accuracy: 0.667200
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.5540 Validation Accuracy: 0.704000
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.6898 Validation Accuracy: 0.648800
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.6282 Validation Accuracy: 0.694200
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.7711 Validation Accuracy: 0.651200
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.6819 Validation Accuracy: 0.645200
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.5531 Validation Accuracy: 0.690800
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.6382 Validation Accuracy: 0.677000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.6778 Validation Accuracy: 0.687800
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.6703 Validation Accuracy: 0.679600
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.5845 Validation Accuracy: 0.677800
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.4940 Validation Accuracy: 0.707800
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.6990 Validation Accuracy: 0.659400
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.6187 Validation Accuracy: 0.694000
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.5985 Validation Accuracy: 0.704000
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.6335 Validation Accuracy: 0.659800
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.5959 Validation Accuracy: 0.693200
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.6828 Validation Accuracy: 0.660600
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.5885 Validation Accuracy: 0.707800
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.5792 Validation Accuracy: 0.716400
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.5399 Validation Accuracy: 0.694000
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.6166 Validation Accuracy: 0.678800
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.7052 Validation Accuracy: 0.639800
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.6739 Validation Accuracy: 0.685000
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.6524 Validation Accuracy: 0.693000
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.5231 Validation Accuracy: 0.683800
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.5640 Validation Accuracy: 0.681000
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.6448 Validation Accuracy: 0.689000
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.5760 Validation Accuracy: 0.707800
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.6520 Validation Accuracy: 0.690800
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.5468 Validation Accuracy: 0.700000
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.5664 Validation Accuracy: 0.689200
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.6007 Validation Accuracy: 0.688600
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.5706 Validation Accuracy: 0.718200
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.5594 Validation Accuracy: 0.726000
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.5141 Validation Accuracy: 0.701000
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.5036 Validation Accuracy: 0.704800
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.5643 Validation Accuracy: 0.691000
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.5380 Validation Accuracy: 0.712800
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.5515 Validation Accuracy: 0.720200
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.5561 Validation Accuracy: 0.688600
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.4743 Validation Accuracy: 0.706400
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.6156 Validation Accuracy: 0.682400
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.5316 Validation Accuracy: 0.707800
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.7183 Validation Accuracy: 0.667400
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.5229 Validation Accuracy: 0.705000
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.4938 Validation Accuracy: 0.715400
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.5556 Validation Accuracy: 0.702000
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.5493 Validation Accuracy: 0.702800
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.6107 Validation Accuracy: 0.704200
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.4913 Validation Accuracy: 0.705200
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.5576 Validation Accuracy: 0.699600
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.5947 Validation Accuracy: 0.678000
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.5232 Validation Accuracy: 0.722800
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.5291 Validation Accuracy: 0.719000
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.4815 Validation Accuracy: 0.709600
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.4913 Validation Accuracy: 0.717800
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.5783 Validation Accuracy: 0.682800
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.5525 Validation Accuracy: 0.704000
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.5535 Validation Accuracy: 0.723600
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.4411 Validation Accuracy: 0.718200
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.4549 Validation Accuracy: 0.708400
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.5726 Validation Accuracy: 0.671600
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.4991 Validation Accuracy: 0.714200
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.5868 Validation Accuracy: 0.707400
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.4226 Validation Accuracy: 0.713000
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.5308 Validation Accuracy: 0.699800
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.5865 Validation Accuracy: 0.677600
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.5039 Validation Accuracy: 0.713400
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.5158 Validation Accuracy: 0.726000
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.4471 Validation Accuracy: 0.714000
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.4335 Validation Accuracy: 0.718400
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.5032 Validation Accuracy: 0.687400
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.5079 Validation Accuracy: 0.723600
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.5556 Validation Accuracy: 0.719600
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.3923 Validation Accuracy: 0.718600
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.4337 Validation Accuracy: 0.726800
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.5469 Validation Accuracy: 0.700600
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.4825 Validation Accuracy: 0.715600
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.5049 Validation Accuracy: 0.730600
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.4059 Validation Accuracy: 0.726600
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.5181 Validation Accuracy: 0.706000
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.4872 Validation Accuracy: 0.715400
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.5395 Validation Accuracy: 0.716000
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.5680 Validation Accuracy: 0.715200
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.4845 Validation Accuracy: 0.708200
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.4385 Validation Accuracy: 0.727200
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.5557 Validation Accuracy: 0.689000
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.4995 Validation Accuracy: 0.715200
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.4840 Validation Accuracy: 0.735000
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.4182 Validation Accuracy: 0.717800
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.3841 Validation Accuracy: 0.722600
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.5166 Validation Accuracy: 0.700600
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.5218 Validation Accuracy: 0.694600
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.5377 Validation Accuracy: 0.719400
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.4165 Validation Accuracy: 0.722000
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.4163 Validation Accuracy: 0.725400
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.4967 Validation Accuracy: 0.717400
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.4554 Validation Accuracy: 0.738000
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.6016 Validation Accuracy: 0.694400
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.4346 Validation Accuracy: 0.731000
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.4008 Validation Accuracy: 0.730600
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.4527 Validation Accuracy: 0.719600
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.4841 Validation Accuracy: 0.715600
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.5227 Validation Accuracy: 0.727200
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.3890 Validation Accuracy: 0.742800
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.4227 Validation Accuracy: 0.727400
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.5128 Validation Accuracy: 0.705600
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.5139 Validation Accuracy: 0.727800
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.5041 Validation Accuracy: 0.726400
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.3717 Validation Accuracy: 0.740800
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.3717 Validation Accuracy: 0.738800
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.4593 Validation Accuracy: 0.705400
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.4917 Validation Accuracy: 0.727600
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.5527 Validation Accuracy: 0.727800
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.3654 Validation Accuracy: 0.739000
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.3823 Validation Accuracy: 0.740400
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.4498 Validation Accuracy: 0.725000
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.4823 Validation Accuracy: 0.735000
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.5079 Validation Accuracy: 0.733000
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.4150 Validation Accuracy: 0.716200
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.3847 Validation Accuracy: 0.732000
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.4546 Validation Accuracy: 0.702400
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.5354 Validation Accuracy: 0.709600
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.5047 Validation Accuracy: 0.734200
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.4290 Validation Accuracy: 0.713600
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.3600 Validation Accuracy: 0.732800
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.4980 Validation Accuracy: 0.701800
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.4639 Validation Accuracy: 0.735000
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.4442 Validation Accuracy: 0.737400
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.3458 Validation Accuracy: 0.740800
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.3476 Validation Accuracy: 0.744000
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.4365 Validation Accuracy: 0.721800
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.4413 Validation Accuracy: 0.729400
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.4023 Validation Accuracy: 0.743000
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.3649 Validation Accuracy: 0.730800
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.4224 Validation Accuracy: 0.726000
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.4118 Validation Accuracy: 0.707000
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.4355 Validation Accuracy: 0.741600
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.4420 Validation Accuracy: 0.742400
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.3395 Validation Accuracy: 0.753600
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.3771 Validation Accuracy: 0.731200
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.4100 Validation Accuracy: 0.717200
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.4193 Validation Accuracy: 0.749200
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.4760 Validation Accuracy: 0.732400
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.3614 Validation Accuracy: 0.737600
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.3888 Validation Accuracy: 0.734000
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.3964 Validation Accuracy: 0.717800
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.4207 Validation Accuracy: 0.747400
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.4953 Validation Accuracy: 0.727600
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.4153 Validation Accuracy: 0.723000
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.4353 Validation Accuracy: 0.737600
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.3816 Validation Accuracy: 0.727800
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.3819 Validation Accuracy: 0.743000
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.4897 Validation Accuracy: 0.718200
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.3785 Validation Accuracy: 0.736200
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.3614 Validation Accuracy: 0.744200
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.4035 Validation Accuracy: 0.728600
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.3914 Validation Accuracy: 0.738800
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.4690 Validation Accuracy: 0.729600
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.3767 Validation Accuracy: 0.735400
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.3407 Validation Accuracy: 0.737800
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.4048 Validation Accuracy: 0.719400
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.4094 Validation Accuracy: 0.738400
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.4421 Validation Accuracy: 0.740400
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.3196 Validation Accuracy: 0.738000
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.4261 Validation Accuracy: 0.727800
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.4552 Validation Accuracy: 0.709200
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.4136 Validation Accuracy: 0.749400
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.5106 Validation Accuracy: 0.719400
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.3569 Validation Accuracy: 0.735200
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.3529 Validation Accuracy: 0.748200
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.4047 Validation Accuracy: 0.720000
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.3912 Validation Accuracy: 0.745600
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.4503 Validation Accuracy: 0.736400
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.3244 Validation Accuracy: 0.738400
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.3561 Validation Accuracy: 0.755800
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.4438 Validation Accuracy: 0.714400
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.4264 Validation Accuracy: 0.737200
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.4565 Validation Accuracy: 0.718400
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.3175 Validation Accuracy: 0.739000
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.3513 Validation Accuracy: 0.743200
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.3637 Validation Accuracy: 0.746800
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.4132 Validation Accuracy: 0.738000
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.4385 Validation Accuracy: 0.733600
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.3471 Validation Accuracy: 0.738000
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.3788 Validation Accuracy: 0.737200
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.3624 Validation Accuracy: 0.743800
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.3728 Validation Accuracy: 0.745800
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.4462 Validation Accuracy: 0.746400
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.2885 Validation Accuracy: 0.745400
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.3893 Validation Accuracy: 0.737400
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.3985 Validation Accuracy: 0.724200
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.4186 Validation Accuracy: 0.734200
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.4335 Validation Accuracy: 0.731800
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.3052 Validation Accuracy: 0.744600
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.3021 Validation Accuracy: 0.753000
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.3397 Validation Accuracy: 0.744200
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.3870 Validation Accuracy: 0.744600
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.3989 Validation Accuracy: 0.748400
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.3035 Validation Accuracy: 0.736200
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.3592 Validation Accuracy: 0.749600
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.4045 Validation Accuracy: 0.731000
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.3477 Validation Accuracy: 0.756600
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.4800 Validation Accuracy: 0.724000
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.3304 Validation Accuracy: 0.730400
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.2838 Validation Accuracy: 0.754800
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.4338 Validation Accuracy: 0.710000
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.3798 Validation Accuracy: 0.756400
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.4604 Validation Accuracy: 0.719600
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.3453 Validation Accuracy: 0.742600
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.4272 Validation Accuracy: 0.734800
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.3615 Validation Accuracy: 0.733600
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.4072 Validation Accuracy: 0.745600
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.4595 Validation Accuracy: 0.731200
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.3165 Validation Accuracy: 0.743600
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.3193 Validation Accuracy: 0.757000
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.3721 Validation Accuracy: 0.733200
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.3826 Validation Accuracy: 0.754000
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.4992 Validation Accuracy: 0.719400
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.3055 Validation Accuracy: 0.747800
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.3198 Validation Accuracy: 0.746000
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.3180 Validation Accuracy: 0.756000
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.3689 Validation Accuracy: 0.744600
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.3910 Validation Accuracy: 0.753000
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.3105 Validation Accuracy: 0.738600
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.3197 Validation Accuracy: 0.753000
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.4058 Validation Accuracy: 0.712000
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.3575 Validation Accuracy: 0.747600
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.3937 Validation Accuracy: 0.748800
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.2804 Validation Accuracy: 0.748200
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.3560 Validation Accuracy: 0.745800
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.3746 Validation Accuracy: 0.728000
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.3480 Validation Accuracy: 0.747000
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.3850 Validation Accuracy: 0.761000
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.3127 Validation Accuracy: 0.747400
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.3071 Validation Accuracy: 0.754000
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.3339 Validation Accuracy: 0.732000
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.3726 Validation Accuracy: 0.746200
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.5175 Validation Accuracy: 0.706600
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.3168 Validation Accuracy: 0.751600
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.3031 Validation Accuracy: 0.748400
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.3924 Validation Accuracy: 0.724000
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.3759 Validation Accuracy: 0.744200
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.4661 Validation Accuracy: 0.731600
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.3269 Validation Accuracy: 0.746000
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.3663 Validation Accuracy: 0.741200
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.3189 Validation Accuracy: 0.744600
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.3520 Validation Accuracy: 0.758200
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.3904 Validation Accuracy: 0.748400
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.3245 Validation Accuracy: 0.739000
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.3140 Validation Accuracy: 0.754400
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.3409 Validation Accuracy: 0.742400
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.3598 Validation Accuracy: 0.752200
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.4592 Validation Accuracy: 0.729600
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.3436 Validation Accuracy: 0.742200
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.3252 Validation Accuracy: 0.760400
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.3046 Validation Accuracy: 0.755200
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.3685 Validation Accuracy: 0.753800
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.3821 Validation Accuracy: 0.752000
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.2900 Validation Accuracy: 0.750800
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.3472 Validation Accuracy: 0.751600
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.3834 Validation Accuracy: 0.734200
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.3438 Validation Accuracy: 0.756200
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.3933 Validation Accuracy: 0.745000
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.2766 Validation Accuracy: 0.747600
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.2982 Validation Accuracy: 0.755800
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.3677 Validation Accuracy: 0.713000
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.3416 Validation Accuracy: 0.749400
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.3853 Validation Accuracy: 0.743200
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.2747 Validation Accuracy: 0.753600
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.3053 Validation Accuracy: 0.759000
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.3356 Validation Accuracy: 0.739200
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.2946 Validation Accuracy: 0.763200
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.4004 Validation Accuracy: 0.744800
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.2741 Validation Accuracy: 0.751200
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.3078 Validation Accuracy: 0.751200
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.3220 Validation Accuracy: 0.748400
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.3544 Validation Accuracy: 0.761600
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.4180 Validation Accuracy: 0.735000
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.2593 Validation Accuracy: 0.746200
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.3146 Validation Accuracy: 0.747000
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.3299 Validation Accuracy: 0.739200
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.3275 Validation Accuracy: 0.759200
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.3928 Validation Accuracy: 0.732000
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.2608 Validation Accuracy: 0.758200
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.2948 Validation Accuracy: 0.748400
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.3500 Validation Accuracy: 0.735800
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.3401 Validation Accuracy: 0.762600
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.3846 Validation Accuracy: 0.739600
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.2699 Validation Accuracy: 0.752400
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.3109 Validation Accuracy: 0.754800
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.3077 Validation Accuracy: 0.737200
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.3229 Validation Accuracy: 0.753600
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.4187 Validation Accuracy: 0.743600
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.3826 Validation Accuracy: 0.714600
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.3482 Validation Accuracy: 0.741600
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.2849 Validation Accuracy: 0.739200
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.3563 Validation Accuracy: 0.748800
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.3450 Validation Accuracy: 0.758000
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.3291 Validation Accuracy: 0.732400
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.2982 Validation Accuracy: 0.748800
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.2838 Validation Accuracy: 0.741400
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.3099 Validation Accuracy: 0.761600
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.3422 Validation Accuracy: 0.760600
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.2818 Validation Accuracy: 0.743000
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.2571 Validation Accuracy: 0.763200
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.3000 Validation Accuracy: 0.744600
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.3330 Validation Accuracy: 0.752200
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.3986 Validation Accuracy: 0.735000
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.2518 Validation Accuracy: 0.755200
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.2546 Validation Accuracy: 0.762400
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.3396 Validation Accuracy: 0.742600
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.3079 Validation Accuracy: 0.761600
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.4663 Validation Accuracy: 0.712000
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.3083 Validation Accuracy: 0.742400
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.3061 Validation Accuracy: 0.757800
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.3714 Validation Accuracy: 0.723600
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.3316 Validation Accuracy: 0.748800
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.3700 Validation Accuracy: 0.751000
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.2873 Validation Accuracy: 0.744600
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.3171 Validation Accuracy: 0.758200
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.2713 Validation Accuracy: 0.757200
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.3351 Validation Accuracy: 0.749200
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.3775 Validation Accuracy: 0.742000
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.2917 Validation Accuracy: 0.742800
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.2856 Validation Accuracy: 0.755000
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.3171 Validation Accuracy: 0.751000
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.3308 Validation Accuracy: 0.747400
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.3444 Validation Accuracy: 0.741200
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.2862 Validation Accuracy: 0.752600
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.3274 Validation Accuracy: 0.757600
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.3135 Validation Accuracy: 0.746000
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.3137 Validation Accuracy: 0.753400
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.3478 Validation Accuracy: 0.751400
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.3045 Validation Accuracy: 0.741400
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.2801 Validation Accuracy: 0.761600
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.3460 Validation Accuracy: 0.722000
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.3191 Validation Accuracy: 0.752200
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.3846 Validation Accuracy: 0.749800
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.2484 Validation Accuracy: 0.755600
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.2587 Validation Accuracy: 0.762000
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.2901 Validation Accuracy: 0.736600
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.3267 Validation Accuracy: 0.754000
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.3858 Validation Accuracy: 0.732000
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.2891 Validation Accuracy: 0.735200
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.2558 Validation Accuracy: 0.765200
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.3102 Validation Accuracy: 0.730400
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.3073 Validation Accuracy: 0.772800
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.3683 Validation Accuracy: 0.737800
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.2931 Validation Accuracy: 0.748000
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.2705 Validation Accuracy: 0.758000
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.2923 Validation Accuracy: 0.732800

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.72451171875

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
